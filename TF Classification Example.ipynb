# %%
import pandas as pd

# %%
diabetes = pd.read_csv('Tensorflow-Bootcamp-master/02-TensorFlow-Basics/pima-indians-diabetes.csv')

# %%
diabetes.head() #in 'Class', 1 means they do have diabetes, 0 means they don't
#trying to predict Class field
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree'] #columns to normalize; all except class to predict, strings, and categorical (e.g. group and Age)

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x-x.min()) / (x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
#these are continuous features
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
#these are categorical features; two methods: vocabulary list or hash bucket; 4 categories
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])

# %%
#assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group',hash_bucket_size=10) #at most 10 possible values for the category

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80]) #taking a continuous value and making it categorical

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,assigned_group,
            age_bucket] #list of all tf.feature columns

# %%
#Train Test Split
x_data = diabetes.drop('Class',axis=1) #only get the features, not the class column

# %%
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.3,random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,
                                                 num_epochs=1000,shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr/model.ckpt.
# INFO:tensorflow:loss = 6.93147, step = 1
# INFO:tensorflow:global_step/sec: 238.956
# INFO:tensorflow:loss = 5.14418, step = 101 (0.419 sec)
# INFO:tensorflow:global_step/sec: 252.992
# INFO:tensorflow:loss = 5.59061, step = 201 (0.397 sec)
# INFO:tensorflow:global_step/sec: 237.397
# INFO:tensorflow:loss = 5.64401, step = 301 (0.421 sec)
# INFO:tensorflow:global_step/sec: 253.143
# INFO:tensorflow:loss = 3.64957, step = 401 (0.394 sec)
# INFO:tensorflow:global_step/sec: 259.742
# INFO:tensorflow:loss = 4.26953, step = 501 (0.386 sec)
# INFO:tensorflow:global_step/sec: 238.021
# INFO:tensorflow:loss = 5.52367, step = 601 (0.420 sec)
# INFO:tensorflow:global_step/sec: 244.259
# INFO:tensorflow:loss = 5.76459, step = 701 (0.409 sec)
# INFO:tensorflow:global_step/sec: 219.333
# INFO:tensorflow:loss = 4.69878, step = 801 (0.458 sec)
# INFO:tensorflow:global_step/sec: 190.2
# INFO:tensorflow:loss = 6.52737, step = 901 (0.528 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.49736.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,
                                                     num_epochs=1,shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-30-14:39:47
# INFO:tensorflow:Restoring parameters from /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-12-30-14:39:48
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.731602, accuracy_baseline = 0.649351, auc = 0.808724, auc_precision_recall = 0.656787, average_loss = 0.524572, global_step = 1000, label/mean = 0.350649, loss = 5.04901, prediction/mean = 0.394423

# %%
results
# Out:
# {'accuracy': 0.73160172,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.80872428,
#  'auc_precision_recall': 0.65678686,
#  'average_loss': 0.52457231,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.0490088,
#  'prediction/mean': 0.39442322}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,
                                                     shuffle=False)
#with predictions, don't pass in a y-value since that's what we're trying to predict

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Restoring parameters from /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmpxmsqnunr/model.ckpt-1000

# %%
my_pred
# Out:
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57128888], dtype=float32),
#   'logits': array([ 0.28711164], dtype=float32),
#   'probabilities': array([ 0.42871115,  0.57128888], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66168594], dtype=float32),
#   'logits': array([ 0.67081618], dtype=float32),
#   'probabilities': array([ 0.33831412,  0.66168594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40805498], dtype=float32),
#   'logits': array([-0.37201178], dtype=float32),
#   'probabilities': array([ 0.59194499,  0.40805498], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39559394], dtype=float32),
#   'logits': array([-0.42385805], dtype=float32),
#   'probabilities': array([ 0.60440606,  0.39559394], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16694537], dtype=float32),
#   'logits': array([-1.6074326], dtype=float32),
#   'probabilities': array([ 0.83305466,  0.16694537], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75494301], dtype=float32),
#   'logits': array([ 1.12515163], dtype=float32),
#   'probabilities': array([ 0.24505696,  0.75494301], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62848878], dtype=float32),
#   'logits': array([ 0.52573895], dtype=float32),
#   'probabilities': array([ 0.37151128,  0.62848878], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34133199], dtype=float32),
#   'logits': array([-0.65736401], dtype=float32),
#   'probabilities': array([ 0.65866798,  0.34133199], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27609682], dtype=float32),
#   'logits': array([-0.96390611], dtype=float32),
#   'probabilities': array([ 0.72390324,  0.27609682], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26305902], dtype=float32),
#   'logits': array([-1.03012943], dtype=float32),
#   'probabilities': array([ 0.73694098,  0.26305902], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14467306], dtype=float32),
#   'logits': array([-1.77700734], dtype=float32),
#   'probabilities': array([ 0.85532695,  0.14467306], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18271145], dtype=float32),
#   'logits': array([-1.49808407], dtype=float32),
#   'probabilities': array([ 0.81728858,  0.18271145], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29982078], dtype=float32),
#   'logits': array([-0.84815139], dtype=float32),
#   'probabilities': array([ 0.70017922,  0.29982078], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.61432868], dtype=float32),
#   'logits': array([ 0.46554446], dtype=float32),
#   'probabilities': array([ 0.38567138,  0.61432868], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20405826], dtype=float32),
#   'logits': array([-1.36112046], dtype=float32),
#   'probabilities': array([ 0.79594171,  0.20405824], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41636285], dtype=float32),
#   'logits': array([-0.33772242], dtype=float32),
#   'probabilities': array([ 0.58363718,  0.41636282], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44637957], dtype=float32),
#   'logits': array([-0.2153095], dtype=float32),
#   'probabilities': array([ 0.5536204,  0.4463796], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14023742], dtype=float32),
#   'logits': array([-1.81331944], dtype=float32),
#   'probabilities': array([ 0.85976255,  0.14023742], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37787136], dtype=float32),
#   'logits': array([-0.49859309], dtype=float32),
#   'probabilities': array([ 0.62212867,  0.37787133], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16392533], dtype=float32),
#   'logits': array([-1.62930691], dtype=float32),
#   'probabilities': array([ 0.83607465,  0.16392533], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25151923], dtype=float32),
#   'logits': array([-1.0905261], dtype=float32),
#   'probabilities': array([ 0.7484808 ,  0.25151923], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33787206], dtype=float32),
#   'logits': array([-0.67279148], dtype=float32),
#   'probabilities': array([ 0.66212791,  0.33787206], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.69392163], dtype=float32),
#   'logits': array([ 0.81851768], dtype=float32),
#   'probabilities': array([ 0.30607843,  0.69392163], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25423288], dtype=float32),
#   'logits': array([-1.0761627], dtype=float32),
#   'probabilities': array([ 0.74576712,  0.25423288], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21434772], dtype=float32),
#   'logits': array([-1.29891479], dtype=float32),
#   'probabilities': array([ 0.78565228,  0.21434772], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.81167889], dtype=float32),
#   'logits': array([ 1.4609561], dtype=float32),
#   'probabilities': array([ 0.18832114,  0.81167889], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19613037], dtype=float32),
#   'logits': array([-1.41065753], dtype=float32),
#   'probabilities': array([ 0.80386966,  0.19613038], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36231312], dtype=float32),
#   'logits': array([-0.56533861], dtype=float32),
#   'probabilities': array([ 0.63768691,  0.36231312], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.11109009], dtype=float32),
#   'logits': array([-2.07965446], dtype=float32),
#   'probabilities': array([ 0.88890988,  0.11109008], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62506694], dtype=float32),
#   'logits': array([ 0.51111102], dtype=float32),
#   'probabilities': array([ 0.37493312,  0.62506694], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.95297998], dtype=float32),
#   'logits': array([ 3.00902104], dtype=float32),
#   'probabilities': array([ 0.04701999,  0.95297998], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42795902], dtype=float32),
#   'logits': array([-0.29018325], dtype=float32),
#   'probabilities': array([ 0.57204098,  0.427959  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38401774], dtype=float32),
#   'logits': array([-0.47252941], dtype=float32),
#   'probabilities': array([ 0.61598229,  0.38401777], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57609576], dtype=float32),
#   'logits': array([ 0.30676627], dtype=float32),
#   'probabilities': array([ 0.42390427,  0.57609576], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29047838], dtype=float32),
#   'logits': array([-0.89306188], dtype=float32),
#   'probabilities': array([ 0.70952165,  0.29047838], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41224408], dtype=float32),
#   'logits': array([-0.35469615], dtype=float32),
#   'probabilities': array([ 0.58775592,  0.41224408], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54031581], dtype=float32),
#   'logits': array([ 0.16161418], dtype=float32),
#   'probabilities': array([ 0.45968416,  0.54031581], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66058075], dtype=float32),
#   'logits': array([ 0.66588342], dtype=float32),
#   'probabilities': array([ 0.33941922,  0.66058075], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.80418289], dtype=float32),
#   'logits': array([ 1.41264558], dtype=float32),
#   'probabilities': array([ 0.19581711,  0.80418289], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33150461], dtype=float32),
#   'logits': array([-0.70138776], dtype=float32),
#   'probabilities': array([ 0.66849542,  0.33150464], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20294306], dtype=float32),
#   'logits': array([-1.36800075], dtype=float32),
#   'probabilities': array([ 0.79705691,  0.20294303], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55991489], dtype=float32),
#   'logits': array([ 0.24081647], dtype=float32),
#   'probabilities': array([ 0.44008517,  0.55991489], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18628226], dtype=float32),
#   'logits': array([-1.47435045], dtype=float32),
#   'probabilities': array([ 0.81371772,  0.18628226], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.54627466], dtype=float32),
#   'logits': array([ 0.18562996], dtype=float32),
#   'probabilities': array([ 0.45372531,  0.54627466], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16425391], dtype=float32),
#   'logits': array([-1.6269114], dtype=float32),
#   'probabilities': array([ 0.83574605,  0.16425391], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13191533], dtype=float32),
#   'logits': array([-1.88412893], dtype=float32),
#   'probabilities': array([ 0.86808467,  0.13191533], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63103074], dtype=float32),
#   'logits': array([ 0.536641], dtype=float32),
#   'probabilities': array([ 0.36896935,  0.63103074], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21113557], dtype=float32),
#   'logits': array([-1.31809402], dtype=float32),
#   'probabilities': array([ 0.78886449,  0.2111356 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23446542], dtype=float32),
#   'logits': array([-1.1832664], dtype=float32),
#   'probabilities': array([ 0.76553458,  0.23446539], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13990417], dtype=float32),
#   'logits': array([-1.81608617], dtype=float32),
#   'probabilities': array([ 0.86009586,  0.13990417], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20642114], dtype=float32),
#   'logits': array([-1.34663451], dtype=float32),
#   'probabilities': array([ 0.79357886,  0.20642112], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26424101], dtype=float32),
#   'logits': array([-1.02404094], dtype=float32),
#   'probabilities': array([ 0.73575896,  0.26424104], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30240458], dtype=float32),
#   'logits': array([-0.83587354], dtype=float32),
#   'probabilities': array([ 0.69759542,  0.30240458], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37371635], dtype=float32),
#   'logits': array([-0.51630628], dtype=float32),
#   'probabilities': array([ 0.62628365,  0.37371632], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14526005], dtype=float32),
#   'logits': array([-1.77227163], dtype=float32),
#   'probabilities': array([ 0.85473996,  0.14526005], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27168247], dtype=float32),
#   'logits': array([-0.98610318], dtype=float32),
#   'probabilities': array([ 0.7283175 ,  0.27168247], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24784224], dtype=float32),
#   'logits': array([-1.11015368], dtype=float32),
#   'probabilities': array([ 0.75215775,  0.24784222], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24876717], dtype=float32),
#   'logits': array([-1.10519826], dtype=float32),
#   'probabilities': array([ 0.7512328 ,  0.24876715], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.53270644], dtype=float32),
#   'logits': array([ 0.13101292], dtype=float32),
#   'probabilities': array([ 0.46729353,  0.53270644], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1860787], dtype=float32),
#   'logits': array([-1.47569394], dtype=float32),
#   'probabilities': array([ 0.81392127,  0.1860787 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26382068], dtype=float32),
#   'logits': array([-1.02620411], dtype=float32),
#   'probabilities': array([ 0.73617929,  0.26382068], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68581456], dtype=float32),
#   'logits': array([ 0.78062391], dtype=float32),
#   'probabilities': array([ 0.31418544,  0.68581456], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67682397], dtype=float32),
#   'logits': array([ 0.7392143], dtype=float32),
#   'probabilities': array([ 0.32317597,  0.67682397], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52910191], dtype=float32),
#   'logits': array([ 0.11653924], dtype=float32),
#   'probabilities': array([ 0.47089812,  0.52910191], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4322049], dtype=float32),
#   'logits': array([-0.27286088], dtype=float32),
#   'probabilities': array([ 0.5677951 ,  0.43220484], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51272267], dtype=float32),
#   'logits': array([ 0.05090165], dtype=float32),
#   'probabilities': array([ 0.48727736,  0.51272267], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20666991], dtype=float32),
#   'logits': array([-1.34511638], dtype=float32),
#   'probabilities': array([ 0.79333007,  0.20666994], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22673777], dtype=float32),
#   'logits': array([-1.22682405], dtype=float32),
#   'probabilities': array([ 0.7732622 ,  0.22673777], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16662316], dtype=float32),
#   'logits': array([-1.60975111], dtype=float32),
#   'probabilities': array([ 0.83337682,  0.16662318], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15118951], dtype=float32),
#   'logits': array([-1.72530186], dtype=float32),
#   'probabilities': array([ 0.84881049,  0.15118951], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.63855469], dtype=float32),
#   'logits': array([ 0.56909657], dtype=float32),
#   'probabilities': array([ 0.36144531,  0.63855469], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27207941], dtype=float32),
#   'logits': array([-0.98409796], dtype=float32),
#   'probabilities': array([ 0.72792059,  0.27207944], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.44077566], dtype=float32),
#   'logits': array([-0.23801458], dtype=float32),
#   'probabilities': array([ 0.55922431,  0.44077569], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.62686169], dtype=float32),
#   'logits': array([ 0.51877666], dtype=float32),
#   'probabilities': array([ 0.37313834,  0.62686169], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.36287543], dtype=float32),
#   'logits': array([-0.56290561], dtype=float32),
#   'probabilities': array([ 0.6371246 ,  0.36287543], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65324318], dtype=float32),
#   'logits': array([ 0.63332582], dtype=float32),
#   'probabilities': array([ 0.34675682,  0.65324318], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1449471], dtype=float32),
#   'logits': array([-1.77479458], dtype=float32),
#   'probabilities': array([ 0.85505295,  0.1449471 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.66005611], dtype=float32),
#   'logits': array([ 0.66354406], dtype=float32),
#   'probabilities': array([ 0.33994395,  0.66005611], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13578089], dtype=float32),
#   'logits': array([-1.85078382], dtype=float32),
#   'probabilities': array([ 0.86421907,  0.13578089], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55380625], dtype=float32),
#   'logits': array([ 0.21606159], dtype=float32),
#   'probabilities': array([ 0.44619372,  0.55380625], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41126966], dtype=float32),
#   'logits': array([-0.35871911], dtype=float32),
#   'probabilities': array([ 0.58873034,  0.41126966], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.18803631], dtype=float32),
#   'logits': array([-1.46282053], dtype=float32),
#   'probabilities': array([ 0.81196368,  0.18803631], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5914883], dtype=float32),
#   'logits': array([ 0.37012148], dtype=float32),
#   'probabilities': array([ 0.40851167,  0.5914883 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.6245997], dtype=float32),
#   'logits': array([ 0.50911796], dtype=float32),
#   'probabilities': array([ 0.37540033,  0.6245997 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60032034], dtype=float32),
#   'logits': array([ 0.40680003], dtype=float32),
#   'probabilities': array([ 0.39967966,  0.60032034], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19077696], dtype=float32),
#   'logits': array([-1.44496953], dtype=float32),
#   'probabilities': array([ 0.809223  ,  0.19077696], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38742796], dtype=float32),
#   'logits': array([-0.45813668], dtype=float32),
#   'probabilities': array([ 0.61257201,  0.38742793], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17215158], dtype=float32),
#   'logits': array([-1.57045472], dtype=float32),
#   'probabilities': array([ 0.82784843,  0.17215158], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.75875348], dtype=float32),
#   'logits': array([ 1.14585781], dtype=float32),
#   'probabilities': array([ 0.24124646,  0.75875348], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.84026772], dtype=float32),
#   'logits': array([ 1.66022158], dtype=float32),
#   'probabilities': array([ 0.15973225,  0.84026772], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.68079036], dtype=float32),
#   'logits': array([ 0.75740659], dtype=float32),
#   'probabilities': array([ 0.31920958,  0.68079036], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2554425], dtype=float32),
#   'logits': array([-1.06979275], dtype=float32),
#   'probabilities': array([ 0.7445575,  0.2554425], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47941238], dtype=float32),
#   'logits': array([-0.08239722], dtype=float32),
#   'probabilities': array([ 0.52058768,  0.47941235], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38956755], dtype=float32),
#   'logits': array([-0.4491303], dtype=float32),
#   'probabilities': array([ 0.61043245,  0.38956758], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47742677], dtype=float32),
#   'logits': array([-0.09035444], dtype=float32),
#   'probabilities': array([ 0.52257323,  0.47742671], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34840035], dtype=float32),
#   'logits': array([-0.62607801], dtype=float32),
#   'probabilities': array([ 0.65159965,  0.34840038], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46635795], dtype=float32),
#   'logits': array([-0.13477182], dtype=float32),
#   'probabilities': array([ 0.53364205,  0.46635798], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17830032], dtype=float32),
#   'logits': array([-1.52790558], dtype=float32),
#   'probabilities': array([ 0.82169968,  0.17830034], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60612321], dtype=float32),
#   'logits': array([ 0.43104506], dtype=float32),
#   'probabilities': array([ 0.39387682,  0.60612321], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59327263], dtype=float32),
#   'logits': array([ 0.37751091], dtype=float32),
#   'probabilities': array([ 0.40672737,  0.59327263], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29774156], dtype=float32),
#   'logits': array([-0.85807556], dtype=float32),
#   'probabilities': array([ 0.70225841,  0.29774156], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21052538], dtype=float32),
#   'logits': array([-1.32176149], dtype=float32),
#   'probabilities': array([ 0.78947461,  0.21052538], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19698952], dtype=float32),
#   'logits': array([-1.40521729], dtype=float32),
#   'probabilities': array([ 0.80301046,  0.19698951], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32837164], dtype=float32),
#   'logits': array([-0.71555901], dtype=float32),
#   'probabilities': array([ 0.6716283 ,  0.32837164], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37302676], dtype=float32),
#   'logits': array([-0.51925361], dtype=float32),
#   'probabilities': array([ 0.62697321,  0.37302676], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15947787], dtype=float32),
#   'logits': array([-1.66211808], dtype=float32),
#   'probabilities': array([ 0.84052211,  0.15947787], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33545828], dtype=float32),
#   'logits': array([-0.68360001], dtype=float32),
#   'probabilities': array([ 0.66454166,  0.33545828], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2410644], dtype=float32),
#   'logits': array([-1.14685285], dtype=float32),
#   'probabilities': array([ 0.75893563,  0.2410644 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.10375457], dtype=float32),
#   'logits': array([-2.1561861], dtype=float32),
#   'probabilities': array([ 0.89624542,  0.10375457], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1395151], dtype=float32),
#   'logits': array([-1.81932318], dtype=float32),
#   'probabilities': array([ 0.8604849,  0.1395151], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.77983516], dtype=float32),
#   'logits': array([ 1.2647059], dtype=float32),
#   'probabilities': array([ 0.22016487,  0.77983516], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20223887], dtype=float32),
#   'logits': array([-1.37235963], dtype=float32),
#   'probabilities': array([ 0.79776108,  0.20223887], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15288012], dtype=float32),
#   'logits': array([-1.71218812], dtype=float32),
#   'probabilities': array([ 0.84711987,  0.15288012], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16193238], dtype=float32),
#   'logits': array([-1.64391994], dtype=float32),
#   'probabilities': array([ 0.83806765,  0.16193238], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52882773], dtype=float32),
#   'logits': array([ 0.11543906], dtype=float32),
#   'probabilities': array([ 0.47117221,  0.52882773], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.4739244], dtype=float32),
#   'logits': array([-0.10439706], dtype=float32),
#   'probabilities': array([ 0.5260756 ,  0.47392443], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.27609679], dtype=float32),
#   'logits': array([-0.96390617], dtype=float32),
#   'probabilities': array([ 0.72390324,  0.27609682], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.459773], dtype=float32),
#   'logits': array([-0.16125643], dtype=float32),
#   'probabilities': array([ 0.540227  ,  0.45977303], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22312468], dtype=float32),
#   'logits': array([-1.24754906], dtype=float32),
#   'probabilities': array([ 0.77687532,  0.22312471], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28152215], dtype=float32),
#   'logits': array([-0.93692368], dtype=float32),
#   'probabilities': array([ 0.71847785,  0.28152218], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.60185707], dtype=float32),
#   'logits': array([ 0.41320896], dtype=float32),
#   'probabilities': array([ 0.39814293,  0.60185707], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50300109], dtype=float32),
#   'logits': array([ 0.01200449], dtype=float32),
#   'probabilities': array([ 0.49699891,  0.50300109], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15990286], dtype=float32),
#   'logits': array([-1.65895104], dtype=float32),
#   'probabilities': array([ 0.84009719,  0.15990287], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39510542], dtype=float32),
#   'logits': array([-0.42590165], dtype=float32),
#   'probabilities': array([ 0.60489458,  0.39510539], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.70505744], dtype=float32),
#   'logits': array([ 0.87149882], dtype=float32),
#   'probabilities': array([ 0.2949425 ,  0.70505744], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55368859], dtype=float32),
#   'logits': array([ 0.21558547], dtype=float32),
#   'probabilities': array([ 0.44631141,  0.55368859], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.38520375], dtype=float32),
#   'logits': array([-0.46751857], dtype=float32),
#   'probabilities': array([ 0.61479628,  0.38520375], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59488821], dtype=float32),
#   'logits': array([ 0.38421047], dtype=float32),
#   'probabilities': array([ 0.40511179,  0.59488821], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22810669], dtype=float32),
#   'logits': array([-1.21903288], dtype=float32),
#   'probabilities': array([ 0.77189332,  0.22810671], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.22885402], dtype=float32),
#   'logits': array([-1.21479344], dtype=float32),
#   'probabilities': array([ 0.771146  ,  0.22885402], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.15732309], dtype=float32),
#   'logits': array([-1.67828202], dtype=float32),
#   'probabilities': array([ 0.84267694,  0.15732311], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3200984], dtype=float32),
#   'logits': array([-0.75331962], dtype=float32),
#   'probabilities': array([ 0.6799016,  0.3200984], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50826508], dtype=float32),
#   'logits': array([ 0.03306329], dtype=float32),
#   'probabilities': array([ 0.49173492,  0.50826508], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.71474975], dtype=float32),
#   'logits': array([ 0.91856551], dtype=float32),
#   'probabilities': array([ 0.28525028,  0.71474975], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25540796], dtype=float32),
#   'logits': array([-1.06997442], dtype=float32),
#   'probabilities': array([ 0.74459201,  0.25540793], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1865321], dtype=float32),
#   'logits': array([-1.4727031], dtype=float32),
#   'probabilities': array([ 0.81346792,  0.18653211], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.42421085], dtype=float32),
#   'logits': array([-0.305511], dtype=float32),
#   'probabilities': array([ 0.57578915,  0.42421082], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26391226], dtype=float32),
#   'logits': array([-1.02573264], dtype=float32),
#   'probabilities': array([ 0.7360878 ,  0.26391226], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16166627], dtype=float32),
#   'logits': array([-1.64588213], dtype=float32),
#   'probabilities': array([ 0.83833373,  0.16166627], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21291666], dtype=float32),
#   'logits': array([-1.30743337], dtype=float32),
#   'probabilities': array([ 0.78708333,  0.21291664], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13768803], dtype=float32),
#   'logits': array([-1.83462667], dtype=float32),
#   'probabilities': array([ 0.86231196,  0.13768803], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.47824639], dtype=float32),
#   'logits': array([-0.08706927], dtype=float32),
#   'probabilities': array([ 0.52175361,  0.47824645], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7946986], dtype=float32),
#   'logits': array([ 1.35348392], dtype=float32),
#   'probabilities': array([ 0.20530137,  0.7946986 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.80443627], dtype=float32),
#   'logits': array([ 1.41425538], dtype=float32),
#   'probabilities': array([ 0.19556375,  0.80443627], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57190305], dtype=float32),
#   'logits': array([ 0.2896198], dtype=float32),
#   'probabilities': array([ 0.42809695,  0.57190305], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50565422], dtype=float32),
#   'logits': array([ 0.0226177], dtype=float32),
#   'probabilities': array([ 0.49434584,  0.50565422], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5956527], dtype=float32),
#   'logits': array([ 0.3873837], dtype=float32),
#   'probabilities': array([ 0.40434727,  0.5956527 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.12556694], dtype=float32),
#   'logits': array([-1.94073677], dtype=float32),
#   'probabilities': array([ 0.8744331 ,  0.12556694], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.52984113], dtype=float32),
#   'logits': array([ 0.1195066], dtype=float32),
#   'probabilities': array([ 0.47015882,  0.52984113], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.79622293], dtype=float32),
#   'logits': array([ 1.36285233], dtype=float32),
#   'probabilities': array([ 0.20377712,  0.79622293], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43569773], dtype=float32),
#   'logits': array([-0.25864124], dtype=float32),
#   'probabilities': array([ 0.56430227,  0.43569776], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32522869], dtype=float32),
#   'logits': array([-0.72984523], dtype=float32),
#   'probabilities': array([ 0.67477131,  0.32522869], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.3630217], dtype=float32),
#   'logits': array([-0.56227309], dtype=float32),
#   'probabilities': array([ 0.63697833,  0.36302167], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.632837], dtype=float32),
#   'logits': array([ 0.54440689], dtype=float32),
#   'probabilities': array([ 0.36716303,  0.632837  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.26420486], dtype=float32),
#   'logits': array([-1.0242269], dtype=float32),
#   'probabilities': array([ 0.7357952 ,  0.26420489], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67980051], dtype=float32),
#   'logits': array([ 0.75285542], dtype=float32),
#   'probabilities': array([ 0.32019943,  0.67980051], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41847578], dtype=float32),
#   'logits': array([-0.32903373], dtype=float32),
#   'probabilities': array([ 0.58152425,  0.41847575], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.41490042], dtype=float32),
#   'logits': array([-0.3437435], dtype=float32),
#   'probabilities': array([ 0.58509958,  0.41490042], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17963389], dtype=float32),
#   'logits': array([-1.51882994], dtype=float32),
#   'probabilities': array([ 0.82036614,  0.17963389], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23420562], dtype=float32),
#   'logits': array([-1.18471432], dtype=float32),
#   'probabilities': array([ 0.7657944 ,  0.23420562], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21240941], dtype=float32),
#   'logits': array([-1.31046283], dtype=float32),
#   'probabilities': array([ 0.78759062,  0.21240941], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43992925], dtype=float32),
#   'logits': array([-0.2414493], dtype=float32),
#   'probabilities': array([ 0.56007075,  0.43992919], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.164992], dtype=float32),
#   'logits': array([-1.62154424], dtype=float32),
#   'probabilities': array([ 0.83500797,  0.164992  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.79598355], dtype=float32),
#   'logits': array([ 1.36137795], dtype=float32),
#   'probabilities': array([ 0.20401645,  0.79598355], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23005471], dtype=float32),
#   'logits': array([-1.20800233], dtype=float32),
#   'probabilities': array([ 0.76994532,  0.23005472], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.5480414], dtype=float32),
#   'logits': array([ 0.19276023], dtype=float32),
#   'probabilities': array([ 0.4519586,  0.5480414], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17281681], dtype=float32),
#   'logits': array([-1.56579411], dtype=float32),
#   'probabilities': array([ 0.82718319,  0.1728168 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72561622], dtype=float32),
#   'logits': array([ 0.97249341], dtype=float32),
#   'probabilities': array([ 0.27438381,  0.72561622], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34310773], dtype=float32),
#   'logits': array([-0.64947563], dtype=float32),
#   'probabilities': array([ 0.6568923 ,  0.34310773], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23130946], dtype=float32),
#   'logits': array([-1.20093203], dtype=float32),
#   'probabilities': array([ 0.76869059,  0.23130947], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.34514517], dtype=float32),
#   'logits': array([-0.64044857], dtype=float32),
#   'probabilities': array([ 0.65485483,  0.34514517], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39069909], dtype=float32),
#   'logits': array([-0.44437462], dtype=float32),
#   'probabilities': array([ 0.60930097,  0.39069912], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.19796938], dtype=float32),
#   'logits': array([-1.39903438], dtype=float32),
#   'probabilities': array([ 0.80203056,  0.19796938], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73177248], dtype=float32),
#   'logits': array([ 1.00363398], dtype=float32),
#   'probabilities': array([ 0.26822755,  0.73177248], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23938078], dtype=float32),
#   'logits': array([-1.15607738], dtype=float32),
#   'probabilities': array([ 0.76061922,  0.23938078], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.20819554], dtype=float32),
#   'logits': array([-1.33583677], dtype=float32),
#   'probabilities': array([ 0.79180449,  0.20819554], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2512413], dtype=float32),
#   'logits': array([-1.09200299], dtype=float32),
#   'probabilities': array([ 0.74875867,  0.25124127], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.46766993], dtype=float32),
#   'logits': array([-0.12950087], dtype=float32),
#   'probabilities': array([ 0.53233004,  0.46766996], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.29256493], dtype=float32),
#   'logits': array([-0.88295925], dtype=float32),
#   'probabilities': array([ 0.70743507,  0.29256493], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13085172], dtype=float32),
#   'logits': array([-1.89344907], dtype=float32),
#   'probabilities': array([ 0.86914825,  0.1308517 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.85415244], dtype=float32),
#   'logits': array([ 1.76754785], dtype=float32),
#   'probabilities': array([ 0.14584754,  0.85415244], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.7220791], dtype=float32),
#   'logits': array([ 0.95479822], dtype=float32),
#   'probabilities': array([ 0.27792087,  0.7220791 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.56703824], dtype=float32),
#   'logits': array([ 0.26977742], dtype=float32),
#   'probabilities': array([ 0.43296173,  0.56703824], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.74631172], dtype=float32),
#   'logits': array([ 1.07903719], dtype=float32),
#   'probabilities': array([ 0.25368828,  0.74631172], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.13377699], dtype=float32),
#   'logits': array([-1.8679682], dtype=float32),
#   'probabilities': array([ 0.86622304,  0.13377699], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.16155504], dtype=float32),
#   'logits': array([-1.646703], dtype=float32),
#   'probabilities': array([ 0.83844495,  0.16155505], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.24105573], dtype=float32),
#   'logits': array([-1.14690018], dtype=float32),
#   'probabilities': array([ 0.75894427,  0.24105573], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37470186], dtype=float32),
#   'logits': array([-0.51209795], dtype=float32),
#   'probabilities': array([ 0.62529814,  0.37470183], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.43830368], dtype=float32),
#   'logits': array([-0.24804938], dtype=float32),
#   'probabilities': array([ 0.56169635,  0.43830368], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57736194], dtype=float32),
#   'logits': array([ 0.31195331], dtype=float32),
#   'probabilities': array([ 0.42263803,  0.57736194], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.57980621], dtype=float32),
#   'logits': array([ 0.32197773], dtype=float32),
#   'probabilities': array([ 0.42019388,  0.57980621], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.39169946], dtype=float32),
#   'logits': array([-0.44017428], dtype=float32),
#   'probabilities': array([ 0.60830057,  0.39169943], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.35804829], dtype=float32),
#   'logits': array([-0.58384526], dtype=float32),
#   'probabilities': array([ 0.64195174,  0.35804832], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.37295067], dtype=float32),
#   'logits': array([-0.51957905], dtype=float32),
#   'probabilities': array([ 0.62704933,  0.37295067], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21583378], dtype=float32),
#   'logits': array([-1.29011238], dtype=float32),
#   'probabilities': array([ 0.78416622,  0.2158338 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64298862], dtype=float32),
#   'logits': array([ 0.58835912], dtype=float32),
#   'probabilities': array([ 0.35701147,  0.64298862], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1389585], dtype=float32),
#   'logits': array([-1.82396746], dtype=float32),
#   'probabilities': array([ 0.86104149,  0.13895848], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23331265], dtype=float32),
#   'logits': array([-1.18969965], dtype=float32),
#   'probabilities': array([ 0.76668733,  0.23331265], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.55726492], dtype=float32),
#   'logits': array([ 0.23006916], dtype=float32),
#   'probabilities': array([ 0.44273508,  0.55726492], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.40497902], dtype=float32),
#   'logits': array([-0.38476145], dtype=float32),
#   'probabilities': array([ 0.59502095,  0.40497899], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23460995], dtype=float32),
#   'logits': array([-1.18246126], dtype=float32),
#   'probabilities': array([ 0.7653901 ,  0.23460996], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.33432415], dtype=float32),
#   'logits': array([-0.68869185], dtype=float32),
#   'probabilities': array([ 0.66567588,  0.33432412], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30373576], dtype=float32),
#   'logits': array([-0.82957119], dtype=float32),
#   'probabilities': array([ 0.69626421,  0.30373573], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14975102], dtype=float32),
#   'logits': array([-1.7365551], dtype=float32),
#   'probabilities': array([ 0.85024893,  0.14975102], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.23398261], dtype=float32),
#   'logits': array([-1.18595803], dtype=float32),
#   'probabilities': array([ 0.76601738,  0.23398262], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.59888572], dtype=float32),
#   'logits': array([ 0.40082455], dtype=float32),
#   'probabilities': array([ 0.40111423,  0.59888572], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.73761088], dtype=float32),
#   'logits': array([ 1.03358793], dtype=float32),
#   'probabilities': array([ 0.26238909,  0.73761088], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.65878046], dtype=float32),
#   'logits': array([ 0.65786421], dtype=float32),
#   'probabilities': array([ 0.34121954,  0.65878046], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.72285861], dtype=float32),
#   'logits': array([ 0.95868587], dtype=float32),
#   'probabilities': array([ 0.27714139,  0.72285861], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.45681509], dtype=float32),
#   'logits': array([-0.17317104], dtype=float32),
#   'probabilities': array([ 0.54318488,  0.45681509], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.28705129], dtype=float32),
#   'logits': array([-0.90974855], dtype=float32),
#   'probabilities': array([ 0.71294874,  0.28705129], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.51484007], dtype=float32),
#   'logits': array([ 0.05937755], dtype=float32),
#   'probabilities': array([ 0.48516002,  0.51484007], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21722692], dtype=float32),
#   'logits': array([-1.28190029], dtype=float32),
#   'probabilities': array([ 0.78277308,  0.21722692], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.17504109], dtype=float32),
#   'logits': array([-1.55031276], dtype=float32),
#   'probabilities': array([ 0.82495892,  0.17504111], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21060593], dtype=float32),
#   'logits': array([-1.3212769], dtype=float32),
#   'probabilities': array([ 0.78939408,  0.21060593], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.50830603], dtype=float32),
#   'logits': array([ 0.03322709], dtype=float32),
#   'probabilities': array([ 0.49169403,  0.50830603], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.05592937], dtype=float32),
#   'logits': array([-2.82611132], dtype=float32),
#   'probabilities': array([ 0.9440707 ,  0.05592937], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.30534354], dtype=float32),
#   'logits': array([-0.82198], dtype=float32),
#   'probabilities': array([ 0.69465649,  0.30534354], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2027856], dtype=float32),
#   'logits': array([-1.36897445], dtype=float32),
#   'probabilities': array([ 0.79721439,  0.20278558], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.25172585], dtype=float32),
#   'logits': array([-1.0894289], dtype=float32),
#   'probabilities': array([ 0.74827415,  0.25172582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.2822957], dtype=float32),
#   'logits': array([-0.93310243], dtype=float32),
#   'probabilities': array([ 0.7177043 ,  0.28229573], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.32378793], dtype=float32),
#   'logits': array([-0.73641789], dtype=float32),
#   'probabilities': array([ 0.67621207,  0.32378796], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.80594116], dtype=float32),
#   'logits': array([ 1.42384911], dtype=float32),
#   'probabilities': array([ 0.19405888,  0.80594116], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.21085663], dtype=float32),
#   'logits': array([-1.31976962], dtype=float32),
#   'probabilities': array([ 0.78914332,  0.21085662], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.14445989], dtype=float32),
#   'logits': array([-1.77873111], dtype=float32),
#   'probabilities': array([ 0.85554004,  0.14445987], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.64721602], dtype=float32),
#   'logits': array([ 0.60682428], dtype=float32),
#   'probabilities': array([ 0.35278398,  0.64721602], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.49717322], dtype=float32),
#   'logits': array([-0.01130724], dtype=float32),
#   'probabilities': array([ 0.50282681,  0.49717325], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.87294257], dtype=float32),
#   'logits': array([ 1.92723083], dtype=float32),
#   'probabilities': array([ 0.1270574 ,  0.87294257], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67427725], dtype=float32),
#   'logits': array([ 0.72759497], dtype=float32),
#   'probabilities': array([ 0.32572269,  0.67427725], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([ 0.1462529], dtype=float32),
#   'logits': array([-1.76429772], dtype=float32),
#   'probabilities': array([ 0.85374707,  0.1462529 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([ 0.67516237], dtype=float32),
#   'logits': array([ 0.7316277], dtype=float32),
#   'probabilities': array([ 0.32483765,  0.67516237], dtype=float32)}]

# %%
#dense nn classifier 
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,
                                       n_classes=2) #3 layers with 10 neurons each
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmppzha_6z0
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmppzha_6z0', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
#to use a feauture column on a dnn, must pass into an embedding column; else this error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-14d882be69ef> in <module>()
# ----> 1 dnn_model.train(input_fn=input_func,steps=1000)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps)
#     239       hooks.append(training.StopAtStepHook(steps, max_steps))
#     240
# --> 241     loss = self._train_model(input_fn=input_fn, hooks=hooks)
#     242     logging.info('Loss for final step: %s.', loss)
#     243     return self
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks)
#     628           input_fn, model_fn_lib.ModeKeys.TRAIN)
#     629       estimator_spec = self._call_model_fn(features, labels,
# --> 630                                            model_fn_lib.ModeKeys.TRAIN)
#     631       ops.add_to_collection(ops.GraphKeys.LOSSES, estimator_spec.loss)
#     632       all_hooks.extend(hooks)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode)
#     613     if 'config' in model_fn_args:
#     614       kwargs['config'] = self.config
# --> 615     model_fn_results = self._model_fn(features=features, **kwargs)
#     616
#     617     if not isinstance(model_fn_results, model_fn_lib.EstimatorSpec):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _model_fn(features, labels, mode, config)
#     269           dropout=dropout,
#     270           input_layer_partitioner=input_layer_partitioner,
# --> 271           config=config)
#     272     super(DNNClassifier, self).__init__(
#     273         model_fn=_model_fn, model_dir=model_dir, config=config)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/estimator/canned/dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config)
#     100       net = feature_column_lib.input_layer(
#     101           features=features,
# --> 102           feature_columns=feature_columns)
#     103
#     104     for layer_id, num_hidden_units in enumerate(hidden_units):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/feature_column/feature_column.py in input_layer(features, feature_columns, weight_collections, trainable)
#     211           'Items of feature_columns must be a _DenseColumn. '
#     212           'You can wrap a categorical column with an '
# --> 213           'embedding_column or indicator_column. Given: {}'.format(column))
#     214   weight_collections = list(weight_collections or [])
#     215   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
#to use a feauture column on a dnn, must pass into an embedding column 
embedded_group_col = tf.feature_column.embedding_column(assigned_group,dimension=4) 
#dimensions = A,B,C,D

# %%
feat_cols = [num_preg,plasma_gluc,dias_press,tricep,insulin,bmi,diabetes_pedigree,embedded_group_col,
            age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train,y_train,batch_size=10,num_epochs=1000,
                                                shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,
                                      n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmprhnm69sn
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmprhnm69sn', '_tf_random_seed': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_save_checkpoints_steps': None, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmprhnm69sn/model.ckpt.
# INFO:tensorflow:loss = 10.9454, step = 1
# INFO:tensorflow:global_step/sec: 167.657
# INFO:tensorflow:loss = 5.9762, step = 101 (0.606 sec)
# INFO:tensorflow:global_step/sec: 242.604
# INFO:tensorflow:loss = 5.16531, step = 201 (0.408 sec)
# INFO:tensorflow:global_step/sec: 249.245
# INFO:tensorflow:loss = 4.40188, step = 301 (0.406 sec)
# INFO:tensorflow:global_step/sec: 241.067
# INFO:tensorflow:loss = 3.36736, step = 401 (0.407 sec)
# INFO:tensorflow:global_step/sec: 276.684
# INFO:tensorflow:loss = 8.53301, step = 501 (0.367 sec)
# INFO:tensorflow:global_step/sec: 241
# INFO:tensorflow:loss = 4.87628, step = 601 (0.410 sec)
# INFO:tensorflow:global_step/sec: 240.419
# INFO:tensorflow:loss = 5.35219, step = 701 (0.430 sec)
# INFO:tensorflow:global_step/sec: 249.528
# INFO:tensorflow:loss = 5.17547, step = 801 (0.388 sec)
# INFO:tensorflow:global_step/sec: 224.856
# INFO:tensorflow:loss = 7.42611, step = 901 (0.451 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmprhnm69sn/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.87556.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test,y=y_test,batch_size=10,
                                                     num_epochs=1,shuffle=False) 
#only 1 epoch since this is an evaluation

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2017-12-30-17:08:13
# INFO:tensorflow:Restoring parameters from /var/folders/yh/ftwq6yz50j970hfx8k08g4880000gn/T/tmprhnm69sn/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-12-30-17:08:14
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.748918, accuracy_baseline = 0.649351, auc = 0.822839, auc_precision_recall = 0.699593, average_loss = 0.505229, global_step = 1000, label/mean = 0.350649, loss = 4.86283, prediction/mean = 0.312531
# {'accuracy': 0.74891776,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8228395,
#  'auc_precision_recall': 0.69959283,
#  'average_loss': 0.50522906,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.8628297,
#  'prediction/mean': 0.31253079}
